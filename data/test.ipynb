# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv("pred_cells_4_25.csv")  # 替换为你的文件路径

# 提取目标列（保持原始顺序）
selected_cols = ['x', 'y', 'cell_id', 'perimeter', 'area', 'cluster_label']
new_df = df[selected_cols]

# 保存到新文件
new_df.to_csv("selected_columns.csv", index=False)
